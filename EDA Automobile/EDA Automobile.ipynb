# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('automobile_data.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.isna()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# # Replacing ? with na value

# %%
df['normalized-losses'].replace({'?' : 'na'},inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9140\2819691867.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['normalized-losses'].replace({'?' : 'na'},inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                na  alfa-romero       gas        std
# 1            3                na  alfa-romero       gas        std
# 2            1                na  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# # Most expensive car according to price

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')     #replace any non-numeric values (e.g., strings like '?', 'unknown', etc.) with NaN

# %%
df = df.dropna(subset=['price'])               # dropna(): Removes rows with missing (NaN) values.
                                               #subset=['price']: Only considers missing values in the 'price' column.

# %%
most_expensive = df.loc[df['price'].idxmax()]    # .idxmax() → returns the index (row number) of the maximum value in the 'price' column.
                                                 # df.loc[...] → accesses the full row at that index using .loc.

# %%
print("Company:", most_expensive['make'])
print("Price: $", most_expensive['price'])
# Out:
# Company: mercedes-benz
# Price: $ 45400.0

# %% [markdown]
# # Maxium Horse Power

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')  # convert to numbers
df = df.dropna(subset=['horsepower'])  # remove missing HP rows

max_hp = df.groupby('make')['horsepower'].max().sort_values(ascending=False)
display(max_hp)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9140\4163810631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')  # convert to numbers
# make
# jaguar           262.0
# porsche          207.0
# nissan           200.0
# mercedes-benz    184.0
# bmw              182.0
# mercury          175.0
# volvo            162.0
# toyota           161.0
# saab             160.0
# alfa-romero      154.0
# plymouth         145.0
# dodge            145.0
# mitsubishi       145.0
# peugot           142.0
# audi             140.0
# mazda            135.0
# subaru           111.0
# volkswagen       110.0
# honda            101.0
# isuzu             90.0
# chevrolet         70.0
# ...

# %% [markdown]
# #  Total Count of cars

# %%
print(df['make'].value_counts())
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# alfa-romero       3
# chevrolet         3
# jaguar            3
# isuzu             2
# mercury           1
# Name: count, dtype: int64

# %% [markdown]
# # Q)e new regulation

# %%
# Convert price column to numeric
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %%
# Drop rows with missing values in price or engine_location
df = df.dropna(subset=['price', 'engine-location'])

# %%
df['updated_price'] = df.apply(
    lambda row: row['price'] * 2 if row['engine-location'] == 'rear' else row['price'],
    axis=1
)

# %%
print(df[['make', 'engine-location', 'price', 'updated_price']].tail())
# Out:
#       make engine-location    price  updated_price
# 200  volvo           front  16845.0        16845.0
# 201  volvo           front  19045.0        19045.0
# 202  volvo           front  21485.0        21485.0
# 203  volvo           front  22470.0        22470.0
# 204  volvo           front  22625.0        22625.0

# %% [markdown]
# # Q)f sort the data frame according to car and price

# %%
sorted_df = df.sort_values(by=['make', 'price'])
print(sorted_df[['make', 'price']].head(10))
# Out:
#            make    price
# 0   alfa-romero  13495.0
# 1   alfa-romero  16500.0
# 2   alfa-romero  16500.0
# 3          audi  13950.0
# 5          audi  15250.0
# 4          audi  17450.0
# 6          audi  17710.0
# 7          audi  18920.0
# 8          audi  23875.0
# 10          bmw  16430.0

# %% [markdown]
# # Q)G  Create a new column which stores the number of doors in a car as integers.

# %%
print(df[['num-of-doors']])
# Out:
#     num-of-doors
# 0            two
# 1            two
# 2            two
# 3           four
# 4           four
# ..           ...
# 200         four
# 201         four
# 202         four
# 203         four
# 204         four
#
# [199 rows x 1 columns]

# %%
# Create a new column which stores the number of doors in a car as integers.
df['num-of-doors'] = df['num-of-doors'].replace({'four': 4, 'two': 2, '?': None})
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9140\2254734116.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['num-of-doors'] = df['num-of-doors'].replace({'four': 4, 'two': 2, '?': None})

# %%
# Remove rows where number of doors is missing
df = df.dropna(subset=['num-of-doors'])

# %%
# Convert the column to integer type
df['num-of-doors'] = df['num-of-doors'].astype(int)

# %%
print(df[['make', 'num-of-doors']])
# Out:
#             make  num-of-doors
# 0    alfa-romero             2
# 1    alfa-romero             2
# 2    alfa-romero             2
# 3           audi             4
# 4           audi             4
# ..           ...           ...
# 200        volvo             4
# 201        volvo             4
# 202        volvo             4
# 203        volvo             4
# 204        volvo             4
#
# [197 rows x 2 columns]

# %% [markdown]
# # Qh) Calculate which variable/feature/attribute is impacting the price of the car the most.

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'updated_price', 'num_of_doors'],
#       dtype='object')

# %%
# Convert price and other numeric columns to numbers
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df['engine-size'] = pd.to_numeric(df['engine-size'], errors='coerce')
df['curb-weight'] = pd.to_numeric(df['curb-weight'], errors='coerce')

# %%
# Drop rows with missing values in these columns
df = df.dropna(subset=['price', 'horsepower', 'engine-size', 'curb-weight'])

# %%
# Check correlation between price and other columns
correlations = df[['price', 'horsepower', 'engine-size', 'curb-weight']].corr()

# %%
print("Correlation with price:")
print(correlations['price'].sort_values(ascending=False))
# Out:
# Correlation with price:
# price          1.000000
# engine-size    0.873708
# curb-weight    0.834732
# horsepower     0.811953
# Name: price, dtype: float64

# %% [markdown]
# # Qi) Concatenate the two data frames given below firstly row wise and secondly column wise

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845,
171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995,
23600, 61500 , 58900]}

german = pd.DataFrame(GermanCars)
japanese = pd.DataFrame(japaneseCars)

row_concat = pd.concat([german, japanese], ignore_index=True)
print(row_concat)
# Out:
#        Company   Price
# 0         Ford   23845
# 1     Mercedes  171995
# 2          BMV  135925
# 3         Audi   71400
# 4       Toyota   29995
# 5        Honda   23600
# 6       Nissan   61500
# 7  Mitsubishi    58900

# %%
col_wise = pd.concat([german, japanese], axis=1)
print("\nColumn-wise Concatenation:")
print(col_wise)
# Out:
# Column-wise Concatenation:
#     Company   Price      Company  Price
# 0      Ford   23845       Toyota  29995
# 1  Mercedes  171995        Honda  23600
# 2       BMV  135925       Nissan  61500
# 3      Audi   71400  Mitsubishi   58900

# %% [markdown]
# # Qj) Save the first and last 15 records of the dataframe in a separate excel sheet.

# %%
first_15 = df.head(15)

# %%
first_15
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                na  alfa-romero       gas        std
# 1           3                na  alfa-romero       gas        std
# 2           1                na  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                na         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                na         audi       gas        std
# 8           1               158         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# 13          0               188          bmw       gas        std
# ...

# %%
last_15 = df.tail(15)

# %%
last_15
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 190          3               256  volkswagen       gas        std
# 191          0                na  volkswagen       gas        std
# 192          0                na  volkswagen    diesel      turbo
# 193          0                na  volkswagen       gas        std
# 194         -2               103       volvo       gas        std
# 195         -1                74       volvo       gas        std
# 196         -2               103       volvo       gas        std
# 197         -1                74       volvo       gas        std
# 198         -2               103       volvo       gas      turbo
# 199         -1                74       volvo       gas      turbo
# 200         -1                95       volvo       gas        std
# 201         -1                95       volvo       gas      turbo
# 202         -1                95       volvo       gas        std
# ...

# %%
first_15.to_csv('first_15_records.csv', index=False)

# %%
last_15.to_csv('last_15_records.csv', index=False)

# %%
print("CSV files saved: 'first_15_records.csv' and 'last_15_records.csv'")
# Out:
# CSV files saved: 'first_15_records.csv' and 'last_15_records.csv'
